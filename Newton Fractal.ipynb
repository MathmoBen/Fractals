# %% [markdown]
# # Newton Fractal

# %%
#This is an attempt to plot a few basic examples of Newton fractals. Based loosely on:
#https://scipython.com/book2/chapter-8-scipy/examples/the-newton-fractal/

# %% [markdown]
# Recall that the Newton-Raphson procedure takes an approximate zero, $x_n$ of the function $f$ and obtains from it a better approximation, namely $$x_{n+1} = x_n - \frac{f(x_n)}{f'(x_n)}.$$
# A Newton fractle is nothing more than a colouring of a complex number $x_0$ according to which zero of $f$ it appears to converge to after a few iterations of the above.

# %% [markdown]
# ## The usual imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## A couple of preliminaries

# %%
# A list of colors to distinguish the roots.
colors = ['b', 'r', 'g', 'y']

TOL = 1.e-8

# %% [markdown]
# ## The main functions for fractal 1

# %%
def newton(z0, f, fprime, MAX_IT=1000):
    """The Newton-Raphson method applied to f(z).

    Returns the root found, starting with an initial guess, z0, or False
    if no convergence to tolerance TOL was reached within MAX_IT iterations.

    """

    z = z0
    for i in range(MAX_IT):
        dz = f(z)/fprime(z)
        if abs(dz) < TOL:
            return z
        z -= dz
    return False

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-1, 1, -1, 1)):
    """Plot a Newton Fractal by finding the roots of f(z).

    The domain used for the fractal image is the region of the complex plane
    (xmin, xmax, ymin, ymax) where z = x + iy, discretized into n values along
    each axis.

    """

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):
        """Get the index of r in the list roots.

        If r is not in roots, append it to the list.

        """

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1
    
    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## Variant of the above zoomed in

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(0, 1, 0, 1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1
        
    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)
# Out:
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_42604\1702870214.py:11: RuntimeWarning: divide by zero encountered in scalar divide
#   dz = f(z)/fprime(z)
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_42604\1702870214.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   dz = f(z)/fprime(z)

# %% [markdown]
# ## Slightly different zooms

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-0.1, 0.1, -0.1, 0.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-1, 1, 0, 2)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## More interesting polynomial

# %% [markdown]
#  The polynomial $x^3-2x+2$ has the interesting property that 0 and 1 alternate, i.e. these choices of starting points
# never converge to a root of the polynomial. It is therefore interesting to see how the code handles these cases.
# See, for instance, Section 7.2 of "Calculus for the ambitious" by Thomas W. K\"orner.

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-1.1, 1.1, -1.1, 1.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**3 - 2*z - 2
fprime = lambda z: 3*z**2 - 2

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## It's not just polynomials!

# %%
#The below does something similar with the function f(z) = sin(z)

def plot_newton_fractal(f, fprime, n=200, domain=(1.4, 1.6, -0.1, 0.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: np.sin(z)
fprime = lambda z: np.cos(z)

plot_newton_fractal(f, fprime, n=500)
# Out:
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_3704\299599308.py:35: RuntimeWarning: overflow encountered in sin
#   f = lambda z: np.sin(z)
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_3704\299599308.py:36: RuntimeWarning: overflow encountered in cos
#   fprime = lambda z: np.cos(z)
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_3704\1702870214.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   dz = f(z)/fprime(z)
