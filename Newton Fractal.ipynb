# %% [markdown]
# # Newton Fractal

# %% [markdown]
# This is an attempt to plot a few basic examples of Newton fractals. Based loosely on:
#
# https://scipython.com/book2/chapter-8-scipy/examples/the-newton-fractal/

# %% [markdown]
# Recall that the Newton-Raphson procedure takes an approximate zero, $x_n$ of the function $f$ and obtains from it a better approximation, namely $$x_{n+1} = x_n - \frac{f(x_n)}{f'(x_n)}.$$
# A Newton fractle is nothing more than a colouring of a complex number $x_0$ according to which zero of $f$ it appears to converge to after a few iterations of the above.

# %% [markdown]
# ## The usual imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## A couple of preliminaries

# %%
# A list of colors to distinguish the roots.
colors = ['b', 'r', 'g', 'y']

TOL = 1.e-8

# %% [markdown]
# ## The main functions for these fractals

# %%
def newton(z0, f, fprime, MAX_IT=1000):
    """The Newton-Raphson method applied to f(z).

    Returns the root found, starting with an initial guess, z0, or False
    if no convergence to tolerance TOL was reached within MAX_IT iterations.

    """

    z = z0
    for i in range(MAX_IT):
        dz = f(z)/fprime(z)
        if abs(dz) < TOL:
            return z
        z -= dz
    return False

# %% [markdown]
# ## The first fractal using $z^4-1$

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-1, 1, -1, 1)):
    """Plot a Newton Fractal by finding the roots of f(z).

    The domain used for the fractal image is the region of the complex plane
    (xmin, xmax, ymin, ymax) where z = x + iy, discretized into n values along
    each axis.

    """

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):
        """Get the index of r in the list roots.

        If r is not in roots, append it to the list.

        """

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1
    
    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## Variant of the above zoomed in

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(0, 1, 0, 1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1
        
    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)
# Out:
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_42528\1702870214.py:11: RuntimeWarning: divide by zero encountered in scalar divide
#   dz = f(z)/fprime(z)
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_42528\1702870214.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   dz = f(z)/fprime(z)

# %% [markdown]
# ## Slightly different zooms

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-0.1, 0.1, -0.1, 0.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-1, 1, 0, 2)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - 1
fprime = lambda z: 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## More interesting polynomial

# %% [markdown]
#  The polynomial $z^3-2z+2$ has the interesting property that 0 and 1 alternate, i.e. these choices of starting points
# never converge to a root of the polynomial. It is therefore interesting to see how the code handles these cases.
# See, for instance, Section 7.2 of "Calculus for the ambitious" by Thomas W. K\"orner.

# %%
def plot_newton_fractal(f, fprime, n=200, domain=(-1.1, 1.1, -1.1, 1.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**3 - 2*z - 2
fprime = lambda z: 3*z**2 - 2

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## It's not just polynomials!

# %%
#The below does something similar with the function f(z) = sin(z)

def plot_newton_fractal(f, fprime, n=200, domain=(1.4, 1.6, -0.1, 0.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: np.sin(z)
fprime = lambda z: np.cos(z)

plot_newton_fractal(f, fprime, n=500)
# Out:
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_42528\299599308.py:35: RuntimeWarning: overflow encountered in sin
#   f = lambda z: np.sin(z)
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_42528\299599308.py:36: RuntimeWarning: overflow encountered in cos
#   fprime = lambda z: np.cos(z)
# C:\Users\Ben Fairbairn\AppData\Local\Temp\ipykernel_42528\1702870214.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   dz = f(z)/fprime(z)

# %% [markdown]
# # Some polynomials whose roots are not as common as each other

# %% [markdown]
# In the above cases every root was simple, i.e. if $f(z_0)=0$, then $f(z_0)\not=0$. In the below we consider the polynomial $z^2-z^4$ which has simple roots at $z=\pm1$ but a double root at $z=0$.

# %%
#The below does something similar with the function f(z) = x^2 - x^4.

def plot_newton_fractal(f, fprime, n=200, domain=(-2, 2, -2, 2)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**2 - z**4
fprime = lambda z: 2*z - 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# For comparison we consider a polynomial that has the same roots but the multiple root has a greater multiplicity, namely $z^3 - z^5$.

# %%
#The below does something similar with the function f(z) = z^3 - z^5.

def plot_newton_fractal(f, fprime, n=200, domain=(-2, 2, -2, 2)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**3 - z**5
fprime = lambda z: 3*z**2 - 5*z**4

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# For a further comparison we take this even further with the polynomial $z^4 - z^6$.

# %%
#The below does something similar with the function f(z) = x^4 - x^6

def plot_newton_fractal(f, fprime, n=200, domain=(-2, 2, -2, 2)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 - z**6
fprime = lambda z: 4*z**3 - 6*z**5

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# For comparison, the below is based on the polynomial $z(z+1)(z-1)^2$ so that the multiple root is at one extreme, rather than sandwiched between the two.

# %%
#The below does something similar with the function f(z) = z(z+1)(z-1)^2

def plot_newton_fractal(f, fprime, n=200, domain=(-1.1, 1.1, -1.1, 1.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z * (z + 1) * (z - 1)**2
fprime = lambda z: 4*z**3 - 3*z**2 - 2*z + 1

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## Asymmtric examples

# %% [markdown]
# The above examples all have the property that they have a reflectional symmetry about the real axis, simply because they all correspond to having real coefficients. Here we consider more asymmetric examples from polynomials with non-real coefficients. In the first example we, simply because it is easier to compare with the first example we consider the polynomial $z^4+iz-1$.

# %%
#The below does something similar with the function f(z) = z^4 + iz - 1

def plot_newton_fractal(f, fprime, n=200, domain=(-1.1, 1.1, -1.1, 1.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 + 1j*z -1
fprime = lambda z: 4*z**3 +1j

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# For camparison let's next consider $z^4 + iz^2 - 1$.

# %%
#The below does something similar with the function f(z) = z^4 + iz^2 - 1

def plot_newton_fractal(f, fprime, n=200, domain=(-1.1, 1.1, -1.1, 1.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z**4 + 1j*z**2 - 1
fprime = lambda z: 4*z**3 + 2*1j*z

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# Next we consider asymmetric examples with a multipls root, namely $iz^2 - z^4$.

# %%
#The below does something similar with the function f(z) = iz^2 + z^4

def plot_newton_fractal(f, fprime, n=200, domain=(-1.1, 1.1, -1.1, 1.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: 1j*z**2 - z**4
fprime = lambda z: 2*1j*z - 4*z**3

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# Next, $iz^3 - z^5$.

# %%
#The below does something similar with the function f(z) = iz^3 - z^5

def plot_newton_fractal(f, fprime, n=200, domain=(-1.1, 1.1, -1.1, 1.1)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: 1j*z**3 - z**5
fprime = lambda z: 3*1j*z**2 - 5*z**4

plot_newton_fractal(f, fprime, n=500)

# %% [markdown]
# ## Combining the above

# %% [markdown]
# What about a function like $z\sin(z)$ whose zero at $z=0$ is clearly different to the rest?

# %%
#The below does something similar with the function f(z) = zsin(z)

def plot_newton_fractal(f, fprime, n=200, domain=(-3.5, 3.5, -3.5, 3.5)):

    roots = []
    m = np.zeros((n, n))
    
    def get_root_index(roots, r):

        try:
            return np.where(np.isclose(roots, r, atol=TOL))[0][0]
        except IndexError:
            roots.append(r)
            return len(roots) - 1

    xmin, xmax, ymin, ymax = domain
    for ix, x in enumerate(np.linspace(xmin, xmax, n)):
        for iy, y in enumerate(np.linspace(ymin, ymax, n)):
            z0 = x + y*1j
            r = newton(z0, f, fprime)
            if r is not False:
                ir = get_root_index(roots, r)
                m[iy, ix] = ir
    nroots = len(roots)
    if nroots > len(colors):
        # Use a "continuous" colormap if there are too many roots.
        cmap = 'hsv'
    else:
        # Use a list of colors for the colormap: one for each root.
        cmap = ListedColormap(colors[:nroots])
    plt.imshow(m, cmap=cmap, origin='lower')
    plt.axis('off')
    plt.show()

f = lambda z: z*np.sin(z)
fprime = lambda z: np.sin(z)+z*np.cos(z)

plot_newton_fractal(f, fprime, n=500)
